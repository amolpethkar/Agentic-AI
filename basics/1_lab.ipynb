# %% [markdown]
# Lab 1 - Agentic AI - Action Ready

# %%
from dotenv import load_dotenv

# %%
load_dotenv(override=True)
# Out:
# True

# %%
import os

open_api_key = os.getenv("OPENAI_API_KEY")

if open_api_key :
    print(f"Open API Key exists")
else:
    print(f'Open API Key not set - please configure using .env')
# Out:
# Open API Key exists

# %%
from openai import OpenAI

# %%
openai = OpenAI()

# %%
message = [{"role":"user","content":"What is a capital of India?"}]

# %%
response = openai.chat.completions.create(model= 'gpt-4o-mini', messages=message)

from IPython.display import Markdown, display

# %%
display(Markdown(response.choices[0].message.content))
# Out:
# The capital of India is New Delhi.
